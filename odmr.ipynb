# %%
from pathlib import Path
import shutil
import re

PEAK_EXPORT = 0
PEAK_ANALYSIS = 1
PEAK_PLOT = 1

# %%
from odmr_all_data import export_all_peaks_all_samples as export_all
from sample_utils import plot_all_measurements_in_folder as plot_all, BASE_PATH
# if PEAK_EXPORT:
#     export_all()
# if PEAK_PLOT:
#     for subfolder in BASE_PATH.iterdir():
#         if subfolder.is_dir():
#             plot_all(subfolder, "cwODMR", True)

# %%
if PEAK_ANALYSIS:
    from sample_utils_2 import analyze_peak_shifts
    TARGET_AREA = "55"
    analyze_peak_shifts(f"peaks_area{TARGET_AREA}.csv", f"peak_shift_analysis_area{TARGET_AREA}.csv")
# Out:
# Temperature groups found:
# 0C: columns 0/1 (measurement)
# 300C: columns 2/3 (measurement)
# 375C: columns 4/5 (measurement)
# 450C: columns 6/7 (measurement)
# 525C: columns 8/9 (measurement)
# 600C: columns 10/11 (measurement)
# 675C: columns 12/13 (measurement)
# 750C: columns 14/15 (measurement)
#
# Saved 255 peaks to:
# peak_shift_analysis_area55.csv
